# %%
import re

# %%
data = "wishing You all a avery happy New  Year 2023242526... Time is just flying 123"
info = "her mobile number is 1234567890 and (098)_765_4321"

# %%
pat='\d{10}|\(\d{3}\)_\d{3}_\d{4}'

# %%
re.findall(pat,data)
# Out:
# []

# %%
email = "23053260@kiit.ac.in"
mailPattern = '\d*@kiit\.ac\.in'

# %%
re.findall(mailPattern,email)
# Out:
# ['23053260@kiit.ac.in']

# %%
# words start with vowel
# extract all digits from following sentence " I got 3 books for 450 r in 2025"
# count total words using regex
# replace multuple spaces with single space
# remove all punctation marks from a sentence using regex (? @ # $ % .)
# corpus having 5 employees different email addresses in different domains. extract all email addresses.
# extract all urls in a paragraph
# regex to validate indian mobile number starts with (6,7,8,9) and contain 10 digit
# extract all words starting with capital letter
# replace # with @ from a tweet
# write function which converts text to lowercase and remove numbers.
# remove all special characters except a-z 0-9
# split a paragraph using regex
# extract only alphabetic words from " ML 2026 is #awesome!!!!"
# normalise extra white  space and remove leading and trailing spaces.
# extract all years from 2015 to 2025 
# replace all email iDs with token email
# replace all phone numbers in text with token phone
# extract price related words from a customer review
# extract 7 sentiment emojis from a text
# identify duplicate consecutive words in a sentence
# remove common stock words (is are the)
# extract all words greater than 5 from a paragraph
# password chceker
# date dd-mm-yyyy
# sentence which end with a ?
# valid identifier
# text pre processing pipeline that remove all urls, number, punctuations, normalize white space to purify the data.

# %%
str1 = "hello are east yay"
pat1 = r'\b[aeiouAEIOU][a-z]*'
re.findall(pat1,str1)
# Out:
# ['are', 'east']

# %%
str2 = "I got 3 books for 450 Rupees in 2025"
pat2 = r'\d+'
re.findall(pat2,str2)
# Out:
# ['3', '450', '2025']

# %%
str3 = "hi        helloo          jbhuy       yhj"
pat3 = r'\s+'
re.sub(pat3," ",str3)
# Out:
# 'hi helloo jbhuy yhj'

# %%
str4 = "Hello! How are you? Are you 100% alright? Did you used #metoo with your mail@fuck.me ."
pat4 = r'\w+\s*'
re.sub(pat4,'',str4)
# Out:
# '! ? % ? #@..'
