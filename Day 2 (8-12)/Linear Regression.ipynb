# %%
import pandas as pd
df = pd.read_csv("student_scores.csv")
print(df)
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
df.shape
# Out:
# (25, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 532.0 bytes

# %%
df.columns.tolist()
# Out:
# ['Hours', 'Scores']

# %%
print(df.to_string())
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
df.columns
# Out:
# Index(['Hours', 'Scores'], dtype='object')

# %%
x=df[['Hours']] #feature - 2D array
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x.ndim
# Out:
# 2

# %%
x.shape
# Out:
# (25, 1)

# %%
y = df[['Scores']]
y.shape
# Out:
# (25, 1)

# %%
x=df[['Hours']] #feature - 2D array
y = df['Scores'] #label - 1D array
print(x.shape)
print(y.shape)
# Out:
# (25, 1)
# (25,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.4,random_state=40)

# %%
x_train
# Out:
#     Hours
# 4     3.5
# 8     8.3
# 16    2.5
# 22    3.8
# 20    2.7
# 0     2.5
# 9     2.7
# 10    7.7
# 23    6.9
# 12    4.5
# 1     5.1
# 18    6.1
# 5     1.5
# 7     5.5
# 6     9.2

# %%
print(x)
# Out:
#     Hours
# 0     2.5
# 1     5.1
# 2     3.2
# 3     8.5
# 4     3.5
# 5     1.5
# 6     9.2
# 7     5.5
# 8     8.3
# 9     2.7
# 10    7.7
# 11    5.9
# 12    4.5
# 13    3.3
# 14    1.1
# 15    8.9
# 16    2.5
# 17    1.9
# 18    6.1
# 19    7.4
# 20    2.7
# 21    4.8
# 22    3.8
# 23    6.9
# 24    7.8

# %%
print(y)
# Out:
# 0     21
# 1     47
# 2     27
# 3     75
# 4     30
# 5     20
# 6     88
# 7     60
# 8     81
# 9     25
# 10    85
# 11    62
# 12    41
# 13    42
# 14    17
# 15    95
# 16    30
# 17    24
# 18    67
# 19    69
# 20    30
# 21    54
# 22    35
# 23    76
# 24    86
# Name: Scores, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([10.16091281])

# %%
model.intercept_
# Out:
# np.float64(-0.04441193680515454)

# %%
model.score(x_train,y_train)
# Out:
# 0.9615939687084912

# %%
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# [90.38771211 79.21070802 11.13259216 75.14634289 33.48660035 86.32334699
#  48.72796957 32.47050907 59.90497367 19.26132241]

# %%
print(y_test)
# Out:
# 15    95
# 24    86
# 14    17
# 19    69
# 13    42
# 3     75
# 21    54
# 2     27
# 11    62
# 17    24
# Name: Scores, dtype: int64

# %%
new_pred = model.predict(pd.DataFrame({'Hours': [6.9]}))
print(new_pred)
# Out:
# [70.06588648]

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train,color='red')
plt.plot(x_test,y_test,color='blue')
plt.show()
# Out:
# Running cells with 'Python 3.12.6' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'
