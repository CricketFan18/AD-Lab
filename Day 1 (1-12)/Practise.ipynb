# %%
nums = [1,7,-10,34,2,-8]
sum = 0
for num in nums:
    sum += num
print(sum)
# Out:
# 26

# %%
maxNum = max(nums)
print(maxNum)
# Out:
# 34

# %%
nums = [1,2,3,7,2,1,5,6,4,8,5,4]
unique_list = list(set(nums))
print("Unique numbers : ", unique_list)
# Out:
# Unique numbers :  [1, 2, 3, 4, 5, 6, 7, 8]

# %%
import random
colors = ['red','blue','green','yellow']
random_item = random.choice(colors)
print(f"Randomly selected item from {colors} is {random_item}")
# Out:
# Randomly selected item from ['red', 'blue', 'green', 'yellow'] is green

# %%
import random
random_list = []
for _ in range(5):
    random_list.append(random.randomInt(1,100))
print(random_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 4
#       2 random_list = []
#       3 for _ in range(5):
# ----> 4     random_list.append(random.randomInt(1,100))
#       5 print(random_list)
#
# AttributeError: module 'random' has no attribute 'randomInt'

# %%
odd = []
even = []
for num in nums:
    if num % 2 == 0:
        even.append(num)
    else:
        odd.append(num)
print(odd)
print(even)
# Out:
# [1, 7]
# [-10, 34, 2, -8]

# %%
strings = ['pqp','xyzz','aba','4224']
count = 0
for s in strings:
    if s[0] == s[-1]:
        count += 1
print("First and Last Character are same : ",count)
# Out:
# First and Last Character are same :  3

# %% [markdown]
# # strings = list(map(str, input().split()))
# rev_strings = []
# for s in strings:
#     rev_strings.append(s[::-1])
# rev_list = strings[::-1]
# print(rev_strings)
# print(rev_list)

# %%
strings = list(map(str, input().split()))
strings.sort(key = lambda x : len(x))
print(strings)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 strings = list(map(str, input().split()))
#       2 strings.sort(key = lambda x : len(x))
#       3 print(strings)
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
# ...
